# %%
# !python --version
# Out:
# Python 3.10.12

# %%
"안녕하세요"
# Out:
# '안녕하세요'

# %%
'안녕하세요'
# Out:
# '안녕하세요'

# %%
print("안녕")
print("내 이름은 신민아야")
print("개강했다") # print()는 함수임
# Out:
# 안녕
# 내 이름은 신민아야
# 개강했다

# %% [markdown]
# - print()는 함수
#
# - mark down
# # one
# ## two
# ### three
#
# LATEX(레이텍) 싸이
#
#
# $\psi$
#
# 삼지창 표시 눌러도됨

# %% [markdown]
# - ctrl + m + a : 코드 셀 위에 삽입 above
# - ctrl + m + b : 코드 셀 아래에 삽입 below
# - ctrl + m + m : 마크 다운 셀로 변경
# - ctrl  m y : 코드 셀로 변경
# - shift + enter : 해당 셀을 실행하고 커서는 다음 셀
# 도구->단축키 참고

# %%
from IPython.display import YouTubeVideo # IPython.display 패키지에서 가져와라

# %%
YouTubeVideo("d1wx4mCqYF8", 800, 400) # 교수님 컴퓨터 대문자 L이 I처럼 나옴
# 링크 https://www.youtube.com/watch?v=d1wx4mCqYF8 에서 = 뒤의 주소
